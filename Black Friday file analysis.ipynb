# %%
import pandas as pd

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']

# %%
del df['Product_Category_3']

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %% [markdown]
# # analyse part now

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.columns.values
# Out:
# array(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation',
#        'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status',
#        'Product_Category_1', 'Purchase'], dtype=object)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %%
for i in df.columns:
    print(i , " : ", df[i].nunique())
# Out:
# User_ID  :  5891
# Product_ID  :  3623
# Gender  :  2
# Age  :  7
# Occupation  :  21
# City_Category  :  3
# Stay_In_Current_City_Years  :  5
# Marital_Status  :  2
# Product_Category_1  :  18
# Purchase  :  17959

# %%
df.groupby('Gender').size().plot( kind = 'pie',
                                  autopct = '%.1f',
                                  title = 'How much males n female in purchasing market')
# Out:
# <AxesSubplot:title={'center':'How much males n female in purchasing market'}, ylabel='None'>

# %%
df.groupby('Gender').size().plot( kind = 'bar',
                                  #autopct = '%.1f',
                                  title = 'How much males n female in purchasing market')
# Out:
# <AxesSubplot:title={'center':'How much males n female in purchasing market'}, xlabel='Gender'>

# %%
df.groupby('Gender').sum()['Purchase'].plot( kind = 'pie',
                                  autopct = '%.1f',
                                  title = 'How much *total money spend* males n female in purchasing market')
# Out:
# <AxesSubplot:title={'center':'How much *total money spend* males n female in purchasing market'}, ylabel='Purchase'>

# %%
df.groupby('Gender').mean()['Purchase'].plot( kind = 'pie',
                                  autopct = '%.1f',
                                  title = 'How much money spend by each males n female in purchasing market')
# Out:
# <AxesSubplot:title={'center':'How much money spend by each males n female in purchasing market'}, ylabel='Purchase'>

# %% [markdown]
# # Some deeper analysis :-

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot( kind = 'bar' ,
                               title = ' Purchase Distribution among age categories'  )
# Out:
# <AxesSubplot:title={'center':' Purchase Distribution among age categories'}, xlabel='Age'>

# %%
for i in df['Age'].unique():       #age by classification of purchasing
    print(i , len(df[df['Age'] == i]))
# Out:
# 0-17 14707
# 55+ 20903
# 26-35 214690
# 46-50 44526
# 51-55 37618
# 36-45 107499
# 18-25 97634

# %%
list = []
for i in df['Age'].unique():          #age by classification of purchasing unique item
    list.append(['i' , df[df['Age'] == i]['Product_ID'].nunique()])
    
data = pd.DataFrame(list, columns = ["Age", "Products"])

# %%
data
# Out:
#   Age  Products
# 0   i      2300
# 1   i      2573
# 2   i      3419
# 3   i      3099
# 4   i      2877
# 5   i      3318
# 6   i      3213

# %%
data.plot.bar(x = 'Age')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase'].plot( kind = 'bar' ,
                               title = ' Spending Distribution among age categories'  )
# Out:
# <AxesSubplot:title={'center':' Spending Distribution among age categories'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase'].plot( kind = 'pie' ,
                                           autopct = '%.1f',
                                           title = ' Spending Distribution among age categories'  )
# Out:
# <AxesSubplot:title={'center':' Spending Distribution among age categories'}, ylabel='Purchase'>

# %%
#how many are married
df.groupby('Marital_Status').size().plot( kind = 'pie' ,
                                          autopct = '%.1f',
                                          title = ' How many are married'  )
# Out:
# <AxesSubplot:title={'center':' How many are married'}, ylabel='None'>

# %%
#how many married males n females
df.groupby('Gender').size().plot( kind = 'pie' ,
                                          autopct = '%.1f',
                                          title = '  How many married males n females  ')
# Out:
# <AxesSubplot:title={'center':'  How many married males n females  '}, ylabel='None'>

# %% [markdown]
# # now import seaborn and proceed deeper

# %%
import seaborn as sns

# %%
sns.countplot( x='Marital_Status' , hue = 'Age' , data =df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
i = 'Marital_Status'
j = 'Gender'
sns.countplot( x = i , hue = j , data = df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
df.columns.values
# Out:
# array(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation',
#        'City_Category', 'Stay_In_Current_City_Years', 'Marital_Status',
#        'Product_Category_1', 'Purchase'], dtype=object)

# %%
sns.countplot( x='Marital_Status' , hue = 'City_Category' , data =df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.countplot( x='Stay_In_Current_City_Years' , hue = 'Age' , data =df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot( x='Occupation' , hue = 'Age' , data =df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot( x='Age' , hue = 'Gender' , data =df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot( x='City_Category' , hue = 'Age' , data =df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot( kind = 'pie',
                                         title = 'People living in diff cities',
                                        autopct = '%0.1f')
# Out:
# <AxesSubplot:title={'center':'People living in diff cities'}, ylabel='None'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot( kind = 'pie',
                                         title = 'People of diff cities spend  money',
                                        autopct = '%0.1f')
# Out:
# <AxesSubplot:title={'center':'People of diff cities spend  money'}, ylabel='Purchase'>

# %%
df.groupby('City_Category').mean()['Purchase'].plot( kind = 'pie',
                                         title = 'People of diff cities spend money on each item  ..that is their avg spend on item',
                                        autopct = '%0.1f')

# by this we conclude people of city A spend more money on each item..that is purchasung an expensive product
# Out:
# <AxesSubplot:title={'center':'People of diff cities spend money on each item  ..that is their avg spend on item'}, ylabel='Purchase'>

# %%
sns.countplot( x = df['Stay_In_Current_City_Years'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot( x = 'Stay_In_Current_City_Years' , hue = 'Gender' , data = df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot( x = 'Stay_In_Current_City_Years' , hue = 'Marital_Status' , data = df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot( x = 'Stay_In_Current_City_Years' , hue = 'City_Category' , data = df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# # we found that people living in city B, who all stayed for 1 yr in that city and should be male and unmarried  ☝️☝️☝️☝️☝️

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot( kind = 'pie',
                                         title = 'ratio of spending people living time period in all cities',
                                        autopct = '%0.1f')
# Out:
# <AxesSubplot:title={'center':'ratio of spending people living time period in all cities'}, ylabel='Purchase'>

# %% [markdown]
# # with occupation how we make analysis.

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
df.groupby('Occupation').mean()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %% [markdown]
# # 15  , 12  ,17 occupatn vale expensive and  4 no. vale quantity

# %%
sns.countplot( x = 'Occupation' , hue = 'Gender' , data = df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot( x = 'Occupation' , hue = 'Marital_Status' , data = df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot( kind = 'bar')

# occupation no. 0 purchase more diff diff items
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot( kind = 'bar')

#product category 8 , 1 , 5 have the major market share..that is 8 ,5,1 no. of product ctgry are good money making product or best selling items
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot( kind = 'bar')

#gives the lest to most expensive item category
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
# products on which people hv spent most of the money..selling produc
df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot( kind = 'bar',
                                                                             title = 'Products on which people spend most of the moneys')
# Out:
# <AxesSubplot:title={'center':'Products on which people spend most of the moneys'}, xlabel='Product_ID'>

# %%
df.groupby('Product_ID').mean()['Purchase'].nlargest(10).sort_values().plot( kind = 'bar',
                                                                             title = 'Most Expensive')
# Out:
# <AxesSubplot:title={'center':'Most Expensive'}, xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot( kind = 'bar',
                                                                 title = 'Most Selling products')
# Out:
# <AxesSubplot:title={'center':'Most Selling products'}, xlabel='Product_ID'>

# %% [markdown]
# # Found :-
#               most expensive
#               most selling
#               most money spend on product

# %%
sns.countplot(x = 'Product_Category_1' , hue = 'Marital_Status' , data = df)
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1' , hue = 'Gender' , data = df)
# Out:
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # Male , Unmarried , Pr_ID:- 1, 5, 8 khreedne vale max h.

# %%
l = []
for i in range(len(df)):
    l.append(df['Gender'][i] + '_' + str(df['Marital_Status'][i]))
df['Gender_And_Marital_St'] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Gender_And_Marital_St
# 0                   F_0
# 1                   F_0
# 2                   F_0
# 3                   F_0
# ...

# %%
sns.countplot( x = 'Gender_And_Marital_St' , data = df)
# Out:
# <AxesSubplot:xlabel='Gender_And_Marital_St', ylabel='count'>

# %%
sns.countplot( x = 'Gender_And_Marital_St' , hue = 'Age', data = df)
# Out:
# <AxesSubplot:xlabel='Gender_And_Marital_St', ylabel='count'>

# %% [markdown]
# # Unmarried man of age btw 26-35 likely to spend most among all age grp ☝️☝️.

# %% [markdown]
# # Unmarried man of age btw 26-35 of city B likely to spend  most from all age grp👇👇

# %%
sns.countplot( x = 'Gender_And_Marital_St' , hue = 'City_Category', data = df)
# Out:
# <AxesSubplot:xlabel='Gender_And_Marital_St', ylabel='count'>

# %%
l1 = []
for i in range(len(df)):
    l1.append(df['Gender_And_Marital_St'][i] + df['City_Category'][i])
    
df['G_And_MSt_And_C'] = l1

# %%
sns.countplot( x = 'G_And_MSt_And_C' , data = df )
# Out:
# <AxesSubplot:xlabel='G_And_MSt_And_C', ylabel='count'>

# %% [markdown]
# # Here we can understand age range 26-35 unmarried male of city B highest then Unmarried male of city C  Married male of city B  then umarried male of city A who all hv stayed in their city only for 1 yr
